# %%
import pandas_datareader.data as web
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from matplotlib import cm

path = '/System/Library/Fonts/AppleSDGothicNeo.ttc' # 나눔 고딕
font_name = fm.FontProperties(fname=path, size=10).get_name() # 기본 폰트 사이즈 : 10
plt.rc('font', family=font_name)
plt.rc('axes', unicode_minus=False)

## PER 포트폴리오 수익률 보여주기
df_per = web.DataReader('Portfolios_Formed_on_E-P', 'famafrench', start='1900-01-01')
df_per_vw = df_per[0].loc[:, ['Lo 20', 'Qnt 2', 'Qnt 3', 'Qnt 4', 'Hi 20']]
df_per_cum = np.log(1+ df_per_vw / 100).cumsum()
df_per_cum.plot(figsize=(10,6), colormap=cm.jet, legend='reverse', title='PER별 포트폴리오 누적 수익률')

plt.show()
# Out:
# /var/folders/37/3xqx743d5cb6qy5bk6kz43500000gn/T/ipykernel_29116/1239181598.py:12: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   df_per = web.DataReader('Portfolios_Formed_on_E-P', 'famafrench', start='1900-01-01')
# /var/folders/37/3xqx743d5cb6qy5bk6kz43500000gn/T/ipykernel_29116/1239181598.py:12: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   df_per = web.DataReader('Portfolios_Formed_on_E-P', 'famafrench', start='1900-01-01')
# /var/folders/37/3xqx743d5cb6qy5bk6kz43500000gn/T/ipykernel_29116/1239181598.py:12: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   df_per = web.DataReader('Portfolios_Formed_on_E-P', 'famafrench', start='1900-01-01')
# /var/folders/37/3xqx743d5cb6qy5bk6kz43500000gn/T/ipykernel_29116/1239181598.py:12: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   df_per = web.DataReader('Portfolios_Formed_on_E-P', 'famafrench', start='1900-01-01')
# /var/folders/37/3xqx743d5cb6qy5bk6kz43500000gn/T/ipykernel_29116/1239181598.py:12: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   df_per = web.DataReader('Portfolios_Formed_on_E-P', 'famafrench', start='1900-01-01')
# /var/folders/37/3xqx743d5cb6qy5bk6kz43500000gn/T/ipykernel_29116/1239181598.py:12: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   df_per = web.DataReader('Portfolios_Formed_on_E-P', 'famafrench', start='1900-01-01')
# /var/folders/37/3xqx743d5cb6qy5bk6kz43500000gn/T/ipykernel_29116/1239181598.py:12: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   df_per = web.DataReader('Portfolios_Formed_on_E-P', 'famafrench', start='1900-01-01')
# /var/folders/37/3xqx743d5cb6qy5bk6kz43500000gn/T/ipykernel_29116/1239181598.py:12: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   df_per = web.DataReader('Portfolios_Formed_on_E-P', 'famafrench', start='1900-01-01')
