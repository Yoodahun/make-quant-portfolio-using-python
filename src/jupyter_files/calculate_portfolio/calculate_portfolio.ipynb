# %%
from src.controller.portfolio_controller import PortfolioController
from scipy.stats import zscore

"""
밸류포트폴리오 총 점수 상위 20개 구하기

"""

portfolio_controller = PortfolioController()
value_portfolio = portfolio_controller.calculate_value_portfolio(for_portfolio=True)

value_portfolio 
# portfolio_controller.clean_outlier(value_portfolio)
# Out:
#         종목코드        종목명      DY     PBR     PCR     PER    PFCR    PGPR  \
# 17    000320      노루홀딩스  0.0415  0.2390  1.8340  2.9304  2.4736  0.5690
# 52    001120    LX인터내셔널  0.1124  0.3307  1.1883  2.9135  1.4012  0.6977
# 89    001800     오리온홀딩스  0.0471  0.2220  2.0491  2.8126  3.0512  0.8142
# 219   004960       한신공영  0.0426  0.1122  1.1554  3.0552  1.1620  0.7174
# 226   005090     SGC에너지  0.0733  0.3882  1.7983  3.9237  4.8170  1.3110
# 262   005990      매일홀딩스  0.0189  0.1587  0.6838  2.3155  1.0240  0.1594
# 391   010770      평화홀딩스  0.0475  0.3592  0.8593  2.4676  1.2143  0.6120
# 414   011560      세보엠이씨  0.0555  0.4976  1.2435  3.5139  1.6558  1.5786
# 435   012630        HDC  0.0314  0.0981  1.0090  2.7023  4.3925  0.7124
# 447   013520    화승코퍼레이션  0.0250  0.3722  0.6090  3.8315  0.8278  0.3364
# 492   016450  한세예스24홀딩스  0.0542  0.2223  1.2726  3.1096  2.2488  0.2723
# 520   017940         E1  0.0550  0.2754  2.0137  1.6666  2.1992  0.8324
# ...

# %%
from src.controller.portfolio_controller import PortfolioController

"""
모멘텀 포트폴리오 20종목 계산하기

"""
portfolio_controller = PortfolioController()
value_portfolio = portfolio_controller.calculate_momentum_portfolio(for_portfolio=True)

value_portfolio
# Out:
# /Users/yoodahun/Documents/Code/PythonProject/make-quant-portfolio-using-python/src/controller/portfolio_controller.py:76: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   res = float(reg.params / reg.bse)
#         종목코드       종목명       12M    K_ratio
# 31    000660    SK하이닉스  0.980415  84.718007
# 37    000810      삼성화재  0.479714  53.028318
# 356   009420   한올바이오파마  1.075269  59.756013
# 375   010100    한국무브넥스  1.038194  61.406917
# 520   017940        E1  0.349076  59.653462
# 526   018290       브이티  1.773788  67.001890
# 565   022100     포스코DX  6.464986  73.802227
# 666   031980  피에스케이홀딩스  3.683616  58.864074
# 724   034950    한국기업평가  0.164521  59.719153
# 769   036930   주성엔지니어링  2.257979  76.119905
# 802   039030    이오테크닉스  1.747573  69.665814
# 810   039440     에스티아이  2.167808  58.863410
# 882   045660       에이텍  0.593468  56.227675
# 994   054450      텔레칩스  0.922581  81.143318
# ...

# %%
from src.controller.portfolio_controller import PortfolioController

"""
퀄리티 포트폴리오 우량종목 20개 계산하기
"""
portfolio_controller = PortfolioController()

portfolio_controller.calculate_quality_portfolio(for_portfolio=True)
# Out:
#         종목코드      종목명         기준일      ROE       GPA      CFO       부채비율
# 236   005390     신성통상  2024-03-06  15.5255   63.1972  19.0205   165.7470
# 337   008770     호텔신라  2024-03-06  13.5823  118.7448   8.0696   374.6081
# 529   018500     동원금속  2024-03-06  27.1805   25.5539  14.0816   389.7566
# 803   039130     하나투어  2024-03-06  46.5464   64.5913  21.9633   334.4119
# 922   049720   고려신용정보  2024-03-06  30.4668  177.7778  19.7531   114.0049
# 941   051500  CJ프레시웨이  2024-03-06  11.7834   38.6749  19.1932   270.4969
# 966   053060       세동  2024-03-06  35.2239   26.2338  18.6147   244.8507
# 1119  067160   아프리카TV  2024-03-06  23.6240   65.4989  21.1190    91.2606
# 1315  089590     제주항공  2024-03-06  36.6434   18.1435  24.5887   458.2934
# 1341  091810    티웨이항공  2024-03-06  90.2638   20.1386  39.5754  1006.9544
# 1368  094170    동운아나텍  2024-03-06  57.2549   62.6348  33.9980   100.0654
# 1369  094280    효성ITX  2024-03-06  20.8644   29.9203  21.7763   152.5335
# ...

# %%
import matplotlib.pyplot as plt
from src.controller.portfolio_controller import PortfolioController
from src.db.db_executer import *
from scipy.stats import zscore
import numpy as np

portfolio_controller = PortfolioController()

portfolio_controller.calculate_multi_factor_portfolio(count=10)
# Out:
# /Users/yoodahun/Documents/Code/PythonProject/make-quant-portfolio-using-python/src/controller/portfolio_controller.py:76: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   res = float(reg.params / reg.bse)
# /Users/yoodahun/Documents/Code/PythonProject/make-quant-portfolio-using-python/venv/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
#         종목코드      종목명 SEC_NM_KOR      DY     PBR     PCR     PER    PFCR  \
# 17    000320    노루홀딩스        산업재  0.0415  0.2390  1.8340  2.9304  2.4736
# 140   003030   세아제강지주         소재  0.0105  0.4001  1.7565  2.0412  8.8160
# 372   009970  영원무역홀딩스    경기관련소비재  0.0324  0.3004  2.0134  1.5703  2.5509
# 414   011560    세보엠이씨        산업재  0.0555  0.4976  1.2435  3.5139  1.6558
# 514   017670    SK텔레콤  커뮤니케이션서비스  0.0636  0.9095  2.2663  9.7844  5.6821
# ...
