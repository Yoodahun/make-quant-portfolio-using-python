# %%
from src.controller.portfolio_controller import PortfolioController
from scipy.stats import zscore

"""
밸류포트폴리오 총 점수 상위 20개 구하기

"""

portfolio_controller = PortfolioController()
value_portfolio = portfolio_controller.calculate_value_portfolio(for_portfolio=True)

value_portfolio 
# portfolio_controller.clean_outlier(value_portfolio)
# Out:
# True
# True
#         종목코드        종목명      DY     PBR     PCR     PER    PFCR    PGPR  \
# 48    001040         CJ  0.0373  0.1084  0.3498  8.4370  0.5294  0.1746
# 52    001120    LX인터내셔널  0.0965  0.3873  1.0273  2.1771  1.1629  0.7192
# 94    001940   KISCO홀딩스  0.0335  0.1930  1.5233  1.9401  1.6387  1.2332
# 157   003380       하림지주  0.0162  0.1587  0.7777  1.9209  1.7205  0.3943
# 224   005010        휴스틸  0.0713  0.3066  1.4582  1.2989  2.5195  0.8358
# 321   007860         서연  0.0130  0.1670  0.6785  1.1687  1.3836  0.3176
# 324   008060         대덕  0.0612  0.1488  0.7890  3.3994  4.0080  0.9050
# 373   009970    영원무역홀딩스  0.0398  0.2525  1.5635  1.1449  1.9789  0.5301
# 411   011370         서한  0.0491  0.2621  1.3084  5.7380  1.3305  1.4779
# 448   013520    화승코퍼레이션  0.0291  0.3390  0.6816  2.5395  0.9761  0.3064
# 481   015360     예스코홀딩스  0.0769  0.3709  1.0563  5.0000  1.4069  0.9995
# 494   016450  한세예스24홀딩스  0.0566  0.2144  0.7426  4.8384  1.0543  0.2596
# 521   017940         E1  0.0626  0.2515  0.6930  1.5050  0.7058  0.5802
# 755   036530     SNT홀딩스  0.0437  0.1413  1.1471  1.7804  1.3952  0.9085
# 780   037460       삼지전자  0.0575  0.2597  1.2438  2.1268  1.7823  1.0184
# 1003  054800    아이디스홀딩스  0.0206  0.1610  0.9117  1.5874  1.0691  0.5063
# 1219  078930         GS  0.0653  0.2137  1.1367  2.2878  1.6019  0.5068
# 1437  101330       모베이스  0.0193  0.2017  0.8907  3.4389  2.7692  0.4825
# 1997  267250       HD현대  0.0773  0.2028  1.3368  4.5416  3.2633  0.9063
# 2141  317400     자이에스앤디  0.0575  0.2783  1.0062  1.4523  1.0102  0.6603
#
#          POR     PSR
# 48    1.0881  0.0470
# 52    1.6710  0.0755
# 94    1.7557  0.1683
# 157   1.0972  0.0626
# 224   0.9425  0.2656
# 321   0.7443  0.0487
# 324   1.8895  0.1539
# 373   1.0025  0.2213
# 411   2.8373  0.1564
# 448   1.1697  0.0514
# 481   4.1845  0.1292
# 494   1.1306  0.0598
# 521   1.0350  0.0499
# 755   1.4723  0.1400
# 780   1.8230  0.0506
# 1003  1.5276  0.1516
# 1219  0.8918  0.1292
# 1437  1.1526  0.0635
# 1997  1.9983  0.0727
# 2141  1.0931  0.0695

# %%
from src.controller.portfolio_controller import PortfolioController

"""
모멘텀 포트폴리오 20종목 계산하기

"""
portfolio_controller = PortfolioController()
value_portfolio = portfolio_controller.calculate_momentum_portfolio(for_portfolio=True)
# Out:
# True
# True
# /Users/yoodahun/Documents/Code/PythonProject/make-quant-portfolio-using-python/src/controller/portfolio_controller.py:69: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   res = float(reg.params / reg.bse)
#         종목코드       종목명        12M     K_ratio
# 79    001570        금양   9.705394   78.582484
# 173   003670    포스코퓨처엠   1.675595   68.886502
# 196   004370        농심   0.528333   78.807335
# 268   006110     삼아알미늄   2.730337   74.383424
# 288   006740      영풍제지  13.764493   86.372209
# 373   009970   영원무역홀딩스   0.415879   83.096795
# 691   033100      제룡전기   2.201220   85.036359
# 1229  079810      디이엔티   3.183877   62.295446
# 1441  101490    에스앤에스텍   1.135135   77.558164
# 1628  140860    파크시스템스   0.851852  100.985864
# 1696  173130      오파스넷   1.811382   58.232582
# 1781  204270     제이앤티씨   0.874510   61.206069
# 1811  214150      클래시스   1.726316   86.803521
# 1998  267260  HD현대일렉트릭   1.203443   57.801148
# 2029  277810  레인보우로보틱스   3.918831   55.770925
# 2048  287410   제이시스메디칼   1.031884   55.743172
# 2189  335890        비올   2.648148   93.931912
# 2193  336570        원텍   4.336918  114.697440
# 2220  352480  씨앤씨인터내셔널   2.757256  121.968669
# 2237  357550     석경에이티   1.747423   59.742225

# %%
from src.controller.portfolio_controller import PortfolioController

"""
퀄리티 포트폴리오 우량종목 20개 계산하기
"""
portfolio_controller = PortfolioController()

portfolio_controller.calculate_quality_portfolio(for_portfolio=True)
# Out:
# True
# True
#         종목코드      종목명         기준일      ROE       GPA      CFO      부채비율
# 237   005390     신성통상  2023-08-29  23.1617   64.3416  12.5702  190.3092
# 372   009900     명신산업  2023-08-29  34.3532   30.5710  19.1409  125.5168
# 530   018500     동원금속  2023-08-29  28.8205   23.8902  14.2267  462.8123
# 804   039130     하나투어  2023-08-29  16.8123   52.3532  10.9796  349.0437
# 925   049720   고려신용정보  2023-08-29  28.9929  173.6219  17.8932  122.2579
# 969   053060       세동  2023-08-29  44.4805   25.5880  17.8501  269.3182
# 1272  084440      유비온  2023-08-29  15.7706   71.7703  11.9617  200.0000
# 1373  094170    동운아나텍  2023-08-29  33.0667   43.1442  21.4311  152.2667
# 1374  094280    효성ITX  2023-08-29  21.1086   28.9895  15.1638  172.3994
# 1394  096240     크레버스  2023-08-29  24.1919  102.8837  20.0641  371.8978
# 1525  118990     모트렉스  2023-08-29  24.2155   28.1475  14.3774  183.5601
# 1549  123040   엠에스오토텍  2023-08-29  30.5798   22.2960  15.7601  219.5805
# 1715  182360     큐브엔터  2023-08-29  18.8289   29.1590  44.6984  151.2629
# 1829  215200  메가스터디교육  2023-08-29  23.8964   58.6925  22.2008  100.0843
# 1939  248070      솔루엠  2023-08-29  32.0206   25.7877  19.9377  219.0682
# 2012  271830       팸텍  2023-08-29  30.5716   38.6696  28.2251  106.7437
# 2018  272450      진에어  2023-08-29  73.1619   24.0286  41.7338  563.3739
# 2037  282330   BGF리테일  2023-08-29  20.9432   48.5412  22.2430  221.0068
# 2229  353810    이지바이오  2023-08-29  22.6555   29.0526  15.3383  208.7279
# 2287  378850   화승알앤에이  2023-08-29  25.7404   27.4397  10.8558  366.2897

# %%
import matplotlib.pyplot as plt
from src.controller.portfolio_controller import PortfolioController
from src.db.db_executer import *
from scipy.stats import zscore
import numpy as np

portfolio_controller = PortfolioController()

portfolio_controller.calculate_multi_factor_portfolio()
# Out:
# True
# True
# True
# True
# True
# True
# /Users/yoodahun/Documents/Code/PythonProject/make-quant-portfolio-using-python/src/controller/portfolio_controller.py:71: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   res = float(reg.params / reg.bse)
# True
# True
# True
# /Users/yoodahun/Documents/Code/PythonProject/make-quant-portfolio-using-python/venv/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
#         종목코드       종목명 SEC_NM_KOR      DY     PBR     PCR     PER     PFCR  \
# 94    001940  KISCO홀딩스         소재  0.0335  0.1930  1.5233  1.9401   1.6387
# 373   009970   영원무역홀딩스    경기관련소비재  0.0398  0.2525  1.5635  1.1449   1.9789
# 521   017940        E1       유틸리티  0.0626  0.2515  0.6930  1.5050   0.7058
# 585   023910      대한약품       건강관리  0.0236  0.7246  4.6433  6.2143   7.1250
# 1400  096760     JW홀딩스       건강관리  0.0237  0.9258  3.1902  9.3749  45.6152
#
#         PGPR     POR  ...      GPA      CFO      부채비율     12M  K_ratio  \
# 94    1.2332  1.7557  ...  13.5093  10.9361   15.8383  0.2954  29.7955
# 373   0.5301  1.0025  ...  34.1476  11.5764   39.4796  0.4159  83.0968
# 521   0.5802  1.0350  ...  14.8443  12.4292  191.9763  0.2200  14.8697
# 585   2.6197  4.7364  ...  22.5983  12.7496   22.4000  0.0658  16.9781
# 1400  0.7052  2.4667  ...  36.7685   8.1274  257.0541  0.3313   4.5762
#
#       z_quality  z_value  z_momentum     qvm  invest
# 94      -2.4960  -6.9685     -2.6795 -1.2416       Y
# 373     -3.7602  -6.6666     -3.0262 -1.4278       Y
# 521     -3.0619  -7.2429     -3.0619 -1.3947       Y
# 585     -3.0519  -6.7633     -2.0967 -1.2033       Y
# 1400    -3.5071  -6.7897     -2.0625 -1.2571       Y
#
# [5 rows x 22 columns]
